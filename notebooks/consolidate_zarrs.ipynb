# %%
import zarr

path_ppi = "/lustre/utmp/std/MLCAST_radar_data/ES-AEMET-radar_reflectivity-ppi_ZAR_2020-2024_v3.zarr"
path_sri = "/lustre/utmp/std/MLCAST_radar_data/ES-AEMET-rainfall_rate-sri_ZAR_2020-2024_v1_kg.zarr"

# %%
import xarray as xr

ds_ppi = xr.open_zarr(path_ppi, consolidated=True)
ds_sri = xr.open_zarr(path_sri, consolidated=True)

display(ds_ppi)
display(ds_sri)
# Out:
# <xarray.Dataset> Size: 241GB
# Dimensions:        (time: 247771, y: 494, x: 493, missing_times: 15317)
# Coordinates:
#   * time           (time) datetime64[ns] 2MB 2020-01-01 ... 2024-12-31T23:50:00
#   * y              (y) float64 4kB 4.377e+06 4.378e+06 ... 4.869e+06 4.87e+06
#   * x              (x) float64 4kB 4.578e+05 4.588e+05 ... 9.49e+05 9.5e+05
#     lat            (y, x) float32 974kB dask.array<chunksize=(494, 493), meta=np.ndarray>
#     lon            (y, x) float32 974kB dask.array<chunksize=(494, 493), meta=np.ndarray>
#   * missing_times  (missing_times) datetime64[ns] 123kB 2020-01-08T05:30:00 ....
# Data variables:
#     dbz            (time, y, x) float32 241GB dask.array<chunksize=(1, 494, 493), meta=np.ndarray>
#     spatial_ref    int32 4B ...
# Attributes: (12/18)
#     CDI:                               Climate Data Interface version 1.8.2 (...
#     history:                           Converted from NetCDF radar files to Zarr
# ...

# %%
zarr.consolidate_metadata(path_ppi)
zarr.consolidate_metadata(path_sri)
# Out:
# /perm/pred/std/ML/MLCAST/mlcast-dataset-ES-AEMET-reflectivity/.venv/lib/python3.12/site-packages/zarr/api/asynchronous.py:247: ZarrUserWarning: Consolidated metadata is currently not part in the Zarr format 3 specification. It may not be supported by other zarr implementations and may change in the future.
#   warnings.warn(
# <Group file:///lustre/utmp/std/MLCAST_radar_data/ES-AEMET-rainfall_rate-sri_ZAR_2020-2024_v1_kg.zarr>

# %%
ds_ppi = xr.open_zarr(path_ppi, consolidated=True)
ds_sri = xr.open_zarr(path_sri, consolidated=True)

display(ds_ppi)
display(ds_sri)
# Out:
# <xarray.Dataset> Size: 241GB
# Dimensions:        (time: 247771, y: 494, x: 493, missing_times: 15317)
# Coordinates:
#   * time           (time) datetime64[ns] 2MB 2020-01-01 ... 2024-12-31T23:50:00
#   * y              (y) float64 4kB 4.377e+06 4.378e+06 ... 4.869e+06 4.87e+06
#   * x              (x) float64 4kB 4.578e+05 4.588e+05 ... 9.49e+05 9.5e+05
#     lat            (y, x) float32 974kB dask.array<chunksize=(494, 493), meta=np.ndarray>
#     lon            (y, x) float32 974kB dask.array<chunksize=(494, 493), meta=np.ndarray>
#   * missing_times  (missing_times) datetime64[ns] 123kB 2020-01-08T05:30:00 ....
# Data variables:
#     dbz            (time, y, x) float32 241GB dask.array<chunksize=(1, 494, 493), meta=np.ndarray>
#     spatial_ref    int32 4B ...
# Attributes: (12/18)
#     CDI:                               Climate Data Interface version 1.8.2 (...
#     history:                           Converted from NetCDF radar files to Zarr
# ...
